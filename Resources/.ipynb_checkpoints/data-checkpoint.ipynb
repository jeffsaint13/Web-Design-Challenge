# %%
import pandas as pd

# %%
city_data = "../Resources/cities.csv"
city_data_df = pd.read_csv(city_data)
city_data_df.fillna("--", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-450b0600af8e> in <module>
#       1 city_data = "../Resources/cities.csv"
# ----> 2 city_data_df = pd.read_csv(city_data)
#       3 city_data_df.fillna("--", inplace=True)
#
# ...

# %%
city_data_df
# Out:
#                    City  Latitude  Longitude  Humidity  Max Temperature  \
# 0                rabaul   -4.1967   152.1721        78            80.71
# 1              tasiilaq   65.6145   -37.6368        61             6.80
# 2         dan khun thot   15.2085   101.7714        99            71.01
# 3          puerto ayora   -0.7393   -90.3518        83            78.80
# 4              meulaboh    4.1363    96.1285        89            76.66
# ..                  ...       ...        ...       ...              ...
# 562         cravo norte    6.3017   -70.2041        33            94.55
# 563             templin   53.1186    13.5022        69            18.00
# 564           bethanien  -26.5020    17.1583        60            73.62
# 565        richards bay  -28.7830    32.0377        84            76.64
# 566  puerto del rosario   28.5004   -13.8627        77            66.20
#
#      Cloudiness  Wind Speed Country
# 0            68        3.67      PG
# ...

# %%
city_data_df.to_html(header=True)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Humidity</th>\n      <th>Max Temperature</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>rabaul</td>\n      <td>-4.1967</td>\n      <td>152.1721</td>\n      <td>78</td>\n      <td>80.71</td>\n      <td>68</td>\n      <td>3.67</td>\n      <td>PG</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>tasiilaq</td>\n      <td>65.6145</td>\n      <td>-37.6368</td>\n      <td>61</td>\n      <td>6.80</td>\n      <td>20</td>\n      <td>3.44</td>\n      <td>GL</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>dan khun thot</td>\n      <td>15.2085</td>\n      <td>101.7714</td>\n      <td>99</td>\n      <td>71.01</td>\n      <td>23</td>\n      <td>3.67</td>\n      <td>TH</td>\n    </tr>\n    <tr>\n  
# ...
